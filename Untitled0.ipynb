# %%
# Traffic Speed Prediction using Machine Learning (PeMS Data)

# %%
## Research 1: Traditional ML for Traffic Prediction

# This study uses features like traffic flow, occupancy, and time-based features to predict traffic speed using models such as Linear Regression and Random Forest.

# Key takeaway:
# - Simple models can perform well for short-term prediction
# - Strong correlation exists in time-series traffic data

# %%
## Research 2: LSTM for Traffic Prediction

# This approach uses deep learning (LSTM) to capture temporal dependencies in traffic data.

#Key takeaway:
# - Better for long-term prediction
# - More complex and harder to deploy

# %%
## Research 3: Graph-Based Models

#Graph Neural Networks model relationships between road networks and sensors.

# Key takeaway:
# - Most advanced
# - Requires complex data and setup
